# %% [markdown]
# <a class="anchor" id="3-bullet"></a>
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Андрей, приветствую!</b>
#
# Буду рада с тобой познакомиться. Меня зовут Евгения Маракова и я буду ревьюером твоего проекта. Если ты не против, то предлагаю общаться на "ты":) Если удобнее на "вы", то нет проблем, только скажи об этом.
#
# В процессе работы ты встретишь комментарии <font color='green'>зеленого</font>, <font color='gold'>желтого</font> и <font color='red'>красного</font> цветов. Что они значат, смотри ниже:
#     <br/>
#
# <div class="alert alert-success">
# <h2> Ревьюер Евгения <a class="tocSkip"> </h2>
#
# ✅ Самый лучший комментарий. Обозначает, что все выполнено отлично.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Ревьюер Евгения <a class="tocSkip"> </h2>
#
# ⚠️ Комментарий рекомендательного характера. Если внесешь коррективы - проект будет в разы лучше.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Ревьюер Евгения <a class="tocSkip"></h2>
#
#
# ❌ Данный комментарий обязателен к исправлению. Чтобы проект был принят - красные комментарии должны быть доработаны.
# </div>
#
# Увидев мой комментарий, не удаляй его, он будет очень полезен в случае повторной проверки работы😊
#
# Чтобы мы с тобой смогли вести диалог без проблем, я оставлю место для твоих вопросов и пояснений под моим комментарием:)
#
# 👇[Смотреть итоги](#1-bullet)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Ревьюер Евгения <a class="tocSkip"> </h2>
#
# ✅ Приятно поработать еще раз:)
#
# ---
#
# Комментарий студента: Евгения, привет! Спасибо большое за ревью. Направляю откорректированную версию с устраненными ошибками.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Ревьюер Евгения v2<a class="tocSkip"> </h2>
#
# ✅ Андрей, привет еще раз! Молодец, оперативно и верно доработал проект. Работа принята, удачи в обучении!)

# %% [markdown]
# # Часть 1. Проверка гипотезы в Python и составление аналитической записки

# %% [markdown]
# Вы предобработали данные в SQL, и теперь они готовы для проверки гипотезы в Python. Загрузите данные пользователей из Москвы и Санкт-Петербурга c суммой часов их активности из файла yandex_knigi_data.csv. Если работаете локально, скачать файл можно по ссылке.
#
# Проверьте наличие дубликатов в идентификаторах пользователей. Сравните размеры групп, их статистики и распределение.
#
# Напомним, как выглядит гипотеза: пользователи из Санкт-Петербурга проводят в среднем больше времени за чтением и прослушиванием книг в приложении, чем пользователи из Москвы. Попробуйте статистически это доказать, используя одностороннюю проверку гипотезы с двумя выборками:
#
# Нулевая гипотеза $H_0: \mu_{\text{СПб}} \leq \mu_{\text{Москва}}$ <br> Среднее время активности пользователей в Санкт-Петербурге не больше, чем в Москве.
#
# Альтернативная гипотеза $H_1: \mu_{\text{СПб}} > \mu_{\text{Москва}}$ <br> Среднее время активности пользователей в Санкт-Петербурге больше, и это различие статистически значимо.
#
# По результатам анализа данных подготовьте аналитическую записку, в которой опишите:
#
# Выбранный тип t-теста и уровень статистической значимости.
#
# Результат теста, или p-value.
#
# Вывод на основе полученного p-value, то есть интерпретацию результатов.
#
# Одну или две возможные причины, объясняющие полученные результаты.

# %% [markdown]
# ## Напишите заголовок первой части проекта здесь
#
# - Автор: Панов Андрей
# - Дата: 31.03.2026

# %% [markdown]
# ## Цели и задачи проекта
#
# **Цель проекта:** проверка гипотезы о том, что в приложении Яндекс Книги пользователи из Санкт-Петербурга проводят в среднем больше времени за чтением и прослушиванием книг, чем пользователи из Москвы.
#
# **Задачи проекта:**
# - проверить датасет на наличие дубликатов в идентификаторах пользователей;
# - сравнить размеры групп (Санкт-Петербург и Москва), их статистики и распределение;
# - проведение t-теста для проверки статистической значимости полученного результата;
# - подготовка аналитической записки с результатами проверки гипотезы

# %% [markdown]
# ## Описание данных
#
# Файл `yandex_knigi_data.csv` содержит данные пользователей из Москвы и Санкт-Петербурга c суммой часов их активности.

# %% [markdown]
# ## Содержимое проекта
#
# **1. Загрузка данных и знакомство с ними:**
#
# - Загрузка данных;
# - Проверка датафрейма на наличие дубликатов;
# - Проверка датафрейма на аномалии и выбросы;
# - Сравнение размеров групп и статистики;
# - Визуализация распределений
#
# **2. Проверка гипотезы в Python:**
#
# - Проверка гипотезы с применением t-testа с поправкой Уэлча
#
# **3. Аналитическая записка**
#
# ---

# %% [markdown]
# <div class="alert alert-success">
# <h2> Ревьюер Евгения <a class="tocSkip"> </h2>
#
# ✅ Здорово, что развернуто оформил вводную часть. Понятны - цель, задачи и структура проекта. Так будет легче каждому соореентироваться в работе.
#
# ---
#
# Комментарий студента:

# %% [markdown]
# ## 1. Загрузка данных и знакомство с ними
#
# Загрузите данные пользователей из Москвы и Санкт-Петербурга c их активностью (суммой часов чтения и прослушивания) из файла `/datasets/yandex_knigi_data.csv`.

# %%
# импортируем необходимые для анализа данных библиотеки

import pandas as pd
import numpy as np
import scipy.stats as stats
from scipy.stats import shapiro, ttest_ind, mannwhitneyu, norm
from statsmodels.stats.proportion import proportions_ztest, proportion_effectsize
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.stats.power import NormalIndPower
from datetime import timedelta

# %%
# загрузим в датафрейм df данные пользователей из Москвы и Санкт-Петербурга с их активностью

df = pd.read_csv('/datasets/yandex_knigi_data.csv')

# %%
# проверим структуру и содержание датафрейма

df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  8784 non-null   int64
#  1   city        8784 non-null   object
#  2   puid        8784 non-null   int64
#  3   hours       8784 non-null   float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 274.6+ KB
#    Unnamed: 0    city    puid       hours
# 0           0  Москва    9668   26.167776
# 1           1  Москва   16598   82.111217
# 2           2  Москва   80401    4.656906
# 3           3  Москва  140205    1.840556
# 4           4  Москва  248755  151.326434

# %% [markdown]
# Датафрейм состоит из 4 столбцов и 8 784 строк. Пропуски отсутствуют.
#
# Проверим наличие дубликатов:

# %% [markdown]
# <div class="alert alert-success">
# <h2> Ревьюер Евгения <a class="tocSkip"> </h2>
#
# ✅ Данные загружены верно.
#
# ---
#
# Комментарий студента:

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Ревьюер Евгения <a class="tocSkip"> </h2>
#
# ⚠️ Рекомендую удалить столбец `Unnamed: 0`. Он полностью дублирует индексы.
#
# ---
#
# Комментарий студента: Удалил столбец Unnamed.

# %%
# удалим столбец Unnamed из датафрейма, так как он полностью дублирует индексы

df = df.drop(columns=['Unnamed: 0'], errors='ignore')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Ревьюер Евгения v2<a class="tocSkip"> </h2>
#
# ✅ +

# %%
# проверим датафрейм

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   city    8784 non-null   object
#  1   puid    8784 non-null   int64
#  2   hours   8784 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 206.0+ KB

# %%
# проверим наличие дубликатов в столбце с идентификаторами пользователей (puid)

duplicates = df['puid'].duplicated().sum()
print(f'Количество дубликатов по столбцу puid: {duplicates}')
# Out:
# Количество дубликатов по столбцу puid: 244

# %%
# удалим дубликаты по столбцу puid и перепроверим наличие дубликатов после удаления

df = df.drop_duplicates(subset = 'puid', keep = 'first')
duplicates = df['puid'].duplicated().sum()
print(f'Количество дубликатов по столбцу puid после удаления: {duplicates}')
# Out:
# Количество дубликатов по столбцу puid после удаления: 0

# %% [markdown]
# <div class="alert alert-success">
# <h2> Ревьюер Евгения <a class="tocSkip"> </h2>
#
# ✅ Дубли по `puid` удалены верно.
#
# ---
#
# Комментарий студента:

# %% [markdown]
# Проверим датафрейм на аномалии (выбросы):

# %%
# Проверим столбец hours на аномалии (выбросы)

anomaly_hours = df[(df['hours'] < 0) | df['hours'].isna()].shape[0]
print(f'Количество строк с hours < 0 или null: {anomaly_hours}')
# Out:
# Количество строк с hours < 0 или null: 0

# %% [markdown]
# Аномалии не обнаружены.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Ревьюер Евгения <a class="tocSkip"> </h2>
#
# ✅ Прекрасно!
#
# ---
#
# Комментарий студента:

# %%
# разделим данные датафрейма по городам

moscow_data = df[df['city'] == 'Москва']['hours']
spb_data = df[df['city'] == 'Санкт-Петербург']['hours']

# %%
# сравним размеры двух групп по городам

group_size = df.groupby('city').size()
rel_size = group_size / len(df) * 100

print('Абсолютные размеры групп:')
print(group_size)
print('Относительные размеры групп, %')
print(round(rel_size, 1))
# Out:
# Абсолютные размеры групп:
# city
# Москва             6234
# Санкт-Петербург    2306
# dtype: int64
# Относительные размеры групп, %
# city
# Москва             73.0
# Санкт-Петербург    27.0
# dtype: float64

# %% [markdown]
# Численность пользователей из Москвы в 2,7 раз больше численности пользователей из Санкт-Петербурга в рамках эксперементальных групп (6 234 и 2 306 пользователей соотвественно).

# %%
# сравним статистические показатели по городам

stats_by_cities = df.groupby('city')['hours'].describe()

stats_by_cities
# Out:
#                   count       mean        std       min       25%       50%  \
# city
# Москва           6234.0  10.881092  36.851683  0.000018  0.059903  0.924498
# Санкт-Петербург  2306.0  11.264433  39.831755  0.000025  0.060173  0.875355
#
#                       75%         max
# city
# Москва           5.939972  857.209373
# Санкт-Петербург  6.138424  978.764775

# %% [markdown]
# Значения среднего, стандартного отклонения, минимума, максимума, 25%-го и 75%-го квартилей выше у выборки пользователей из Петербурга. При этом показатель медианы (50%) выше у пользователей из Москвы.

# %%
# визуализируем распределение часов активности по городам с помощью гистограммы

plt.figure(figsize = (30, 15))
plt.subplot(1, 2, 1)
sns.histplot(data = df, x = 'hours', hue = 'city', element = 'step', stat = 'density')
plt.title('Распределение часов активности по городам')
plt.xlabel('Часы активности')
plt.ylabel('Плотность')
plt.show();

# %%
# визуализируем распределение часов активности по городам с помощью "ящика с усами"

plt.figure(figsize = (30, 15))
plt.subplot(1, 2, 2)
sns.boxplot(data=df, x='city', y='hours')
plt.title('Ящики с усами для часов активности')
plt.xlabel('Город')
plt.ylabel('Часы активности')
plt.show()

# %% [markdown]
# Графики не демонстрируют значительных различий между показателями в выборках пользователей из Москвы и Санкт-Петербурга.
#
# У выборки пользователей из Санкт-Петербурга "ящик с усами" имеет более длинный хвост, однако основной массив пользователей демонстрирует примерно похожее поведение с пользователями из Москвы.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Ревьюер Евгения <a class="tocSkip"> </h2>
#
# ✅ Есть сравнение размера выборок и их статистик.
#
# ---
#
# Комментарий студента:

# %% [markdown]
# ## 2. Проверка гипотезы в Python
#
# Гипотеза звучит так: пользователи из Санкт-Петербурга проводят в среднем больше времени за чтением и прослушиванием книг в приложении, чем пользователи из Москвы. Попробуйте статистически это доказать, используя одностороннюю проверку гипотезы с двумя выборками:
#
# - Нулевая гипотеза H₀: Средняя активность пользователей в часах в двух группах (Москва и Санкт-Петербург) не различается.
#
# - Альтернативная гипотеза H₁: Средняя активность пользователей в Санкт-Петербурге больше, и это различие статистически значимо.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Ревьюер Евгения <a class="tocSkip"> </h2>
#
# ✅ Супер, гипотезы сформулированы!
#
# ---
#
# Комментарий студента:

# %%
# Примерные данные по группам

df_m = np.array([1.1, 1.3, 1.5, 1.7, 1.9, 2.1, 2.3])
df_s = np.array([2.0, 2.2, 2.4, 2.5, 2.6, 2.7, 2.9])

# %%
# проверим нормальность распределения

p_m = shapiro(df_m).pvalue
p_s = shapiro(df_s).pvalue

print(f"p-value для Москвы: {p_m:.4f}")
print(f"p-value для Санкт-Петербурга: {p_s:.4f}")
# Out:
# p-value для Москвы: 0.9493
# p-value для Санкт-Петербурга: 0.9920

# %%
# выбираем критерий для проверки гипотез

if p_m > 0.05 and p_s > 0.05:
    print("Обе выборки распределены нормально. Применяем t-test (с поправкой Уэлча)")
    stat, p = ttest_ind(df_s, df_m, equal_var=False, alternative='greater')
else:
    print("Одна из выборок нормально не распределена. Применяем U-test (Манна-Уитни)")
    stat, p = mannwhitneyu(df_s, df_m, alternative='greater')

print(f"p-value выбранного теста: {p:.4f}")
# Out:
# Обе выборки распределены нормально. Применяем t-test (с поправкой Уэлча)
# p-value выбранного теста: 0.0014

# %% [markdown]
# Применяем t-test с поправкой Уэлча для проверки гипотез:

# %%
# Проводим одноторонний t-тест Уэлча (т.к. размеры выборок по городам заметно отличаются)

# Уровень значимости
alpha = 0.05

stat_welch_ttest, p_value_welch_ttest = ttest_ind(
    moscow_data,
    spb_data,
    alternative='less' 
)

if p_value_welch_ttest > alpha:
    print(f'p-value теста Уэлча = {round(p_value_welch_ttest, 4)}')
    print('Нулевая гипотеза подтверждается: средняя активность пользователей в часах в двух группах (Москва и Санкт-Петербург) не различается.')
else:
    print(f'p-value теста Уэлча = {round(p_value_welch_ttest, 4)}')
    print('Нулевая гипотеза отвергается: средняя активность пользователей в Санкт-Петербурге больше, и это различие статистически значимо.')
# Out:
# p-value теста Уэлча = 0.3382
# Нулевая гипотеза подтверждается: средняя активность пользователей в часах в двух группах (Москва и Санкт-Петербург) не различается.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Ревьюер Евгения <a class="tocSkip"> </h2>
#
# ✅ Тест выполнен корректно.
#
# ---
#
# Комментарий студента:

# %% [markdown]
# ## 3. Аналитическая записка
#
# Для проверки результата теста использовался **t-test Уэлча** при уровне статистической значимости 5%.
#
# В результате анализа не удалось найти статистическое подтверждения альтернативной гипотезе о том, что пользователи из Санкт-Петербурга проводят больше времени за прочитыванием и прослушиванием контента в приложении. Показатель p-value значительно превышает уровень статистической значимости, и гипотеза о различии между двумя выборками не выявлена.
#
# Причина такого результата может быть связана с особенностями выборок (выборка пользователей из Москвы в 2,7 раза превышает выборку из Санкт-Петербурга. Пользователи обоих городов на деле демонстрируют очень похожее поведение в контексте привычек к чтению и прослушиванию книг).

# %% [markdown]
# <div class="alert alert-success">
# <h2> Ревьюер Евгения <a class="tocSkip"> </h2>
#
# ✅  Аналитическая записка по результатам тестирования сформирована, наполнение соответствует заданию.
#
# ---
#
# Комментарий студента:

# %% [markdown]
# ----

# %% [markdown]
# # Часть 2. Анализ результатов A/B-тестирования

# %% [markdown]
# Теперь вам нужно проанализировать другие данные. Представьте, что к вам обратились представители интернет-магазина BitMotion Kit, в котором продаются геймифицированные товары для тех, кто ведёт здоровый образ жизни. У него есть своя целевая аудитория, даже появились хиты продаж: эспандер со счётчиком и напоминанием, так и подстольный велотренажёр с Bluetooth.
#
# В будущем компания хочет расширить ассортимент товаров. Но перед этим нужно решить одну проблему. Интерфейс онлайн-магазина слишком сложен для пользователей — об этом говорят отзывы.
#
# Чтобы привлечь новых клиентов и увеличить число продаж, владельцы магазина разработали новую версию сайта и протестировали его на части пользователей. По задумке, это решение доказуемо повысит количество пользователей, которые совершат покупку.
#
# Ваша задача — провести оценку результатов A/B-теста. В вашем распоряжении:
#
# * данные о действиях пользователей и распределении их на группы,
#
# * техническое задание.
#
# Оцените корректность проведения теста и проанализируйте его результаты.

# %% [markdown]
# ## 1. Опишите цели исследования.

# %% [markdown]
# **Цель исследования:** Определить, приводит ли новый интерфейс к статистически значимому увеличению доли пользователей, совершающих покупку (конверсия).

# %% [markdown]
# **Гипотезы исследования:**
#
# H₀ (нулевая гипотеза): Конверсия в покупку в тестовой группе (новый интерфейс) не превышает конверсию в контрольной группе (старый интерфейс)
#
# H₁ (альтернативная гипотеза): Конверсия в покупку в тестовой группе выше, чем в контрольной, и это различие статистически значимо

# %% [markdown]
# **Задачи исследования:**
#
# - Проверить корректность проведения теста (соответствие ТЗ, равномерность распределения, отсутствие пересечений с другими тестами);
# - Оценить достаточность выборки для статистически значимых результатов;
# - Провести статистический тест для оценки изменения конверсии;
# - Сделать выводы о влиянии нового интерфейса на пользовательскую активность

# %% [markdown]
# ## 2. Загрузите данные, оцените их целостность.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Ревьюер Евгения <a class="tocSkip"> </h2>
#
# ⚠️ Андрей, все библиотеки стоит импортировать вначале проекта - таким образом, заказчик сможет узнать о проблемах с его окружением сразу перед работой с проектом, а не посреди или в конце проекта. Также сможешь избежать повторного импорта.
#
# ---
#
# Комментарий студента: Переместил все подгружаемые библиотеки в начало проекта. Отсюда убрал, чтобы не было повторного импорта.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Ревьюер Евгения v2<a class="tocSkip"> </h2>
#
# ✅ Все вижу, молодец!

# %%
# загружаем данные для исследования

participants = pd.read_csv('https://code.s3.yandex.net/datasets/ab_test_participants.csv')
events = pd.read_csv('https://code.s3.yandex.net/datasets/ab_test_events.zip',
                     parse_dates=['event_dt'], low_memory=False)

# %%
# проверим целостность данных в таблице participants

participants.info()
print("\nПропуски в participants:")
print(participants.isna().sum())
print("\nДубликаты в participants по user_id:")
print(participants['user_id'].duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14525 entries, 0 to 14524
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_id  14525 non-null  object
#  1   group    14525 non-null  object
#  2   ab_test  14525 non-null  object
#  3   device   14525 non-null  object
# dtypes: object(4)
# memory usage: 454.0+ KB
#
# Пропуски в participants:
# user_id    0
# group      0
# ab_test    0
# device     0
# dtype: int64
#
# Дубликаты в participants по user_id:
# 887

# %% [markdown]
# Пропусков в данных в датафрейме `participants` не выявлено.
#
# В столбце с идентификаторами пользователей `user_id` найдено **887** дубликатов.

# %%
# удаляем строки с дубликатами по столбцу user_id и проверим наличие дубликатов после удаления

participants = participants.drop_duplicates(subset = 'user_id', keep = 'first')
duplicates = participants['user_id'].duplicated().sum()
print(f'Количество дубликатов по столбцу user_id пользователей после удаления: {duplicates}')
# Out:
# Количество дубликатов по столбцу user_id пользователей после удаления: 0

# %% [markdown]
# Дубликаты по столбцу `user_id` в датафрейме `participants` удалены.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Ревьюер Евгения <a class="tocSkip"> </h2>
#
# ✅ Правильно, это будут пересечения в конкурирующим тестом, которые нам не нужны.
#
# Пользователи, на которых оказывалось влияние другим исследованием для нашего исследования могут быть непригодными.
#
# ---
#
# Комментарий студента:

# %%
# проверим целостность данных в таблице events

print("\nТаблица events:")
display(events.info())
print("\nПропуски в events:")
display(events.isna().sum())
print("\nДубликаты в events по user_id, event_dt и event_name:")
print(events[['user_id', 'event_dt', 'event_name']].duplicated().sum())
# Out:
# Таблица events:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 787286 entries, 0 to 787285
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   user_id     787286 non-null  object
#  1   event_dt    787286 non-null  datetime64[ns]
#  2   event_name  787286 non-null  object
#  3   details     249022 non-null  object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 24.0+ MB
# None
# Пропуски в events:
# user_id            0
# event_dt           0
# event_name         0
# details       538264
# dtype: int64
# Дубликаты в events по user_id, event_dt и event_name:
# 39510

# %% [markdown]
# Пропуски содержатся только в столбце `details` (более 50%). Предполагаю, что информация в этом столбце вторичная и наличие этих пропусков не должно сказаться на последующем анализе.
#
# В столбцах `user_id`, `event_dt` и `event_name` найдены дубликаты. Удалим их:

# %%
# удалим строки с дубликатами и проверим наличие дубликатов после удаления

events = events.drop_duplicates(subset = ['user_id', 'event_dt', 'event_name'], keep = 'first')
duplicates = events[['user_id', 'event_dt', 'event_name']].duplicated().sum()
print(f'Количество дубликатов после удаления: {duplicates}')
# Out:
# Количество дубликатов после удаления: 0

# %%
# проверим уникальные значения в датафреймах

print("\nУникальные тесты в participants:")
print(participants['ab_test'].unique())
print("\nУникальные группы в participants:")
print(participants['group'].unique())
print("\nУникальные события в events:")
print(events['event_name'].unique())
# Out:
# Уникальные тесты в participants:
# ['interface_eu_test' 'recommender_system_test']
#
# Уникальные группы в participants:
# ['B' 'A']
#
# Уникальные события в events:
# ['End of Black Friday Ads Campaign' 'registration' 'product_page' 'login'
#  'product_cart' 'purchase' 'Start of Christmas&New Year Promo'
#  'Start of CIS New Year Gift Lottery']

# %% [markdown]
# <div class="alert alert-success">
# <h2> Ревьюер Евгения <a class="tocSkip"> </h2>
#
# ✅ Данные загружены.
#
# Согласна, если пропуски можно оставить без изменений, то дубликаты обработать нужно.
#
# ---
#
# Комментарий студента:

# %% [markdown]
# ## 3. По таблице `ab_test_participants` оцените корректность проведения теста:
#
#    3\.1 Выделите пользователей, участвующих в тесте, и проверьте:
#
#    - соответствие требованиям технического задания,
#
#    - равномерность распределения пользователей по группам теста,
#
#    - отсутствие пересечений с конкурирующим тестом (нет пользователей, участвующих одновременно в двух тестовых группах).

# %%
# отфильтруем пользователей теста

test_name = 'interface_eu_test'
test_participants = participants[participants['ab_test'] == test_name]
if test_participants.empty:
    print(f"Тест {test_name} не найден. Доступные тесты:", participants['ab_test'].unique())
    exit()
else:
    print("\nПользователи теста interface_eu_test:")
    print(test_participants.groupby('group').size())
# Out:
# Пользователи теста interface_eu_test:
# group
# A    5174
# B    5229
# dtype: int64

# %% [markdown]
# Тест соответствует требованиям технического задания. Пользователи распределены по группам теста практически равномерно.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Ревьюер Евгения <a class="tocSkip"> </h2>
#
# ✅ Выделены участники исследуемого теста.
#
# Распределение пользователей по группам равномерное, верно.
#
# ---
#
# Комментарий студента:

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Ревьюер Евгения <a class="tocSkip"> </h2>
#
# ⚠️ Также стоит проверить пересечения между группами теста в пределах изучаемого теста.
#
# ---
#
# Комментарий студента: Ниже дописал код, проверяющий пересечения с конкурирующим тестом.

# %%
# проверим пересечения с конкурирующим тестом

users_in_interface_test = set(participants[participants['ab_test'] == 'interface_eu_test']['user_id'])
users_in_recommender_test = set(participants[participants['ab_test'] == 'recommender_system_test']['user_id'])

common_users = users_in_interface_test.intersection(users_in_recommender_test)

if not common_users:
    print("Нет пользователей, участвующих одновременно в двух тестовых группах.")
else:
    print(f"Есть пересечение: {common_users}")
# Out:
# Нет пользователей, участвующих одновременно в двух тестовых группах.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Ревьюер Евгения v2<a class="tocSkip"> </h2>
#
# ✅ Это ты проверил пересечения между конкурирующими тестами, а не группами теста interface_eu_test (группы А и В). Их не будет, поэтому не ошибка. Но будь внимательнее.

# %% [markdown]
# 3\.2 Проанализируйте данные о пользовательской активности по таблице `ab_test_events`:
#
# - оставьте только события, связанные с участвующими в изучаемом тесте пользователями;

# %%
# оставим только события, связанные с участвующими в изучаемом тесте пользователями

test_users = test_participants['user_id']
events = events[events['user_id'].isin(test_users)]
print("\nСобытия после фильтрации по пользователям теста:", len(events))
# Out:
# События после фильтрации по пользователям теста: 70220

# %% [markdown]
# Для дальнейшей работы с данными оставлено 70 220 событий - они связаны с участвующими в тесте пользователями.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Ревьюер Евгения <a class="tocSkip"> </h2>
#
# ✅  Отобраны события, относящиеся только к нашему тесту.
#
# ---
#
# Комментарий студента:

# %% [markdown]
# - определите горизонт анализа: рассчитайте время (лайфтайм) совершения события пользователем после регистрации и оставьте только те события, которые были выполнены в течение первых семи дней с момента регистрации;

# %%
# определяем горизонт анализа - выводим события в течение первых 7 дней с момента регистрации

registrations = events[events['event_name'] == 'registration'][['user_id', 'event_dt']].rename(columns={'event_dt': 'registration_dt'})
events = events.merge(registrations, on='user_id', how='left')
events['lifetime_days'] = (events['event_dt'] - events['registration_dt']).dt.days
events = events[events['lifetime_days'].between(0, 6, inclusive='both')]
print("\nСобытия в пределах 7 дней после регистрации:", len(events))
# Out:
# События в пределах 7 дней после регистрации: 60690

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Ревьюер Евгения <a class="tocSkip"></h2>
#
# ❌ Андрей, обрати внимание, таким образом, получается 8 дней. Стоит исключить либо 7 день, либо нулевой.
#
# ---
#
#
# Комментарий студента: Согласен, ошибся :) Переписал код на первые 7 дней.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Ревьюер Евгения v2<a class="tocSkip"> </h2>
#
# ✅ Отлично!

# %% [markdown]
# Оцените достаточность выборки для получения статистически значимых результатов A/B-теста. Заданные параметры:
#
# - базовый показатель конверсии — 30%,
#
# - мощность теста — 80%,
#
# - достоверность теста — 95%.

# %%
# зададим параметры А/В-теста

alpha =0.05  
power = 0.8
beta = 1-power
p1 = 0.3
mde=0.03
p2 = p1 + mde

# инициализируем класс NormalIndPower

power_analysis = NormalIndPower()
effect_size = (p2 - p1) / np.sqrt((p1*(1-p1) + p2*(1-p2))/2)

# проверим достаточность выборки

sample_size = power_analysis.solve_power(
    effect_size = effect_size,
    power = power,
    alpha = alpha,
    ratio = 1
)

print(f"Необходимый размер выборки для каждой группы: {int(sample_size)}")
# Out:
# Необходимый размер выборки для каждой группы: 3759

# %% [markdown]
# Выборки в группах для теста являются достаточными для получения статистически значимых результатов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Ревьюер Евгения <a class="tocSkip"> </h2>
#
# ✅ Выполнена оценка достаточности пользователей в группе для проведения теста.
#
#
# ---
#
# Комментарий студента:

# %% [markdown]
# - рассчитайте для каждой группы количество посетителей, сделавших покупку, и общее количество посетителей.

# %%
# рассчитаем для каждой группы количество посетителей, сделавших покупку, и общее количество посетителей

events = events.merge(test_participants[['user_id', 'group']], on = 'user_id', how = 'left')
purchases = events[events['event_name'] == 'purchase']
purchase_counts = purchases.groupby('group')['user_id'].nunique()
total_users = test_participants.groupby('group')['user_id'].nunique()
print("\nКоличество уникальных покупателей по группам:")
print(purchase_counts)
print("\nОбщее количество пользователей по группам:")
print(total_users)
print("\nКонверсия по группам:")
conversion_rates = purchase_counts / total_users
print(conversion_rates)
# Out:
# Количество уникальных покупателей по группам:
# group
# A    1427
# B    1532
# Name: user_id, dtype: int64
#
# Общее количество пользователей по группам:
# group
# A    5174
# B    5229
# Name: user_id, dtype: int64
#
# Конверсия по группам:
# group
# A    0.275802
# B    0.292981
# Name: user_id, dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# <h2> Ревьюер Евгения <a class="tocSkip"> </h2>
#
# ✅  Пользователи по группам и конверсия посчитаны.
#
# ---
#
# Комментарий студента:

# %%
# проверим изменение конверсии между группами

conv_control = conversion_rates.get('A', 0)
conv_test = conversion_rates.get('B', 0)
abs_change = (conv_test - conv_control)*100
print(f'Изменение конверсии между группами: {abs_change:.2f}%')
# Out:
# Изменение конверсии между группами: 1.72%

# %%
# визуализируем конверсию по группам

plt.figure(figsize=(12,6))
sns.barplot(x = conversion_rates.index, y = conversion_rates.values)
plt.title('Конверсия в покупку по группам')
plt.ylabel('Конверсия')
plt.xlabel('Группа')
plt.show()

# %% [markdown]
# - сделайте предварительный общий вывод об изменении пользовательской активности в тестовой группе по сравнению с контрольной.

# %% [markdown]
# Конверсия в группе В также оказалась чуть больше, чем в группе А - 0,275 (около 28%) против 0,292 (около 29%). Изменение конверсии составило **1,7%**, что меньше ожидаемого в техническом задании (3%).
#
# Предварительно можно сделать вывод о недостаточной эффективности внедрения нового интерфейса. Однако для окончательного вердикта требуется оценить статистическую значимость полученного результата.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Ревьюер Евгения <a class="tocSkip"> </h2>
#
# ✅ Сделан вывод о приросте конверсии в тестовой группе.
#
# ---
#
# Комментарий студента:

# %% [markdown]
# ## 4. Проведите оценку результатов A/B-тестирования:

# %% [markdown]
# - Проверьте изменение конверсии подходящим статистическим тестом, учитывая все этапы проверки гипотез.

# %%
# gрименим z-тест пропорций для оценки статистической значимости результата

successes = [purchase_counts.get('B', 0), purchase_counts.get('A', 0)]
nobs = [total_users.get('B', 0), total_users.get('A', 0)]
stat_z, p_value_z = proportions_ztest(successes, nobs, alternative = 'larger')
print(f'\nZ-тест пропорций: Z-статистика= {stat_z:.4f}, p-value = {p_value_z:.4f}')
if p_value_z < 0.05:
    print('Нулевая гипотеза отвергается: конверсия в тестовой группе выше')
else:
    print('Нулевая гипотеза подтверждается: нет доказательств, что конверсия в тестовой группе выше')
# Out:
# Z-тест пропорций: Z-статистика= 1.9419, p-value = 0.0261
# Нулевая гипотеза отвергается: конверсия в тестовой группе выше

# %% [markdown]
# Статистическая значимость полученного результата **подтверждена**.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Ревьюер Евгения <a class="tocSkip"> </h2>
#
# ✅ Тест выполнен корректно.
#
# ---
#
# Комментарий студента:

# %% [markdown]
# - Опишите выводы по проведённой оценке результатов A/B-тестирования. Что можно сказать про результаты A/B-тестирования? Был ли достигнут ожидаемый эффект в изменении конверсии?

# %% [markdown]
# По результатам А/В-тестирования удалось установить, что конверсия в покупку среди тестовой группы, пользовавшейся версией сайта с обновленным интерфейсом, оказалась выше, чем в контрольной группе, пользовавшейся старой версией сайта. Однако положительная динамика составила всего **1,7%** вместо ожидавшихся как минимум 3%.
#
# Статистический тест подтверждает значимость полученного результата. Таким образом, разработка нового интерфейса позволила добиться эффекта в изменении конверсии, однако он оказался меньше уровня, запланированного в ТЗ. В связи с этим рекомендуется рассмотреть возможность и других нововведений, которые были бы способны улучшить конверсию до желаемого уровня.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Ревьюер Евгения <a class="tocSkip"> </h2>
#
# ✅ Отличный итоговый вывод с интерпретацией теста и рекомендациями.
#
# ---
#
# Комментарий студента:

# %% [markdown]
# <a class="anchor" id="1-bullet"></a>
# <div style="border:solid Chocolate 2px; padding: 40px">
# Андрей, спасибо за работу. Осталось исправить несколько комментариев и можно идти к заказчику. Молодец!
#
#
#     Что необходимо доработать:
#
#     1. Исключить 7 день из фильтрации.
#
#     2. Рекомендую:
#     - убрать столбец `Unnamed: 0`;
#     - импортировать библиотеки вначале проекта;
#     - проверить пересечения внутри теста.
#
#
#     Жду новую версию проекта!)
#
# [В начало](#3-bullet)
